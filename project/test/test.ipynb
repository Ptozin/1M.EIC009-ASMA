# %%
from math import radians, cos, sin, asin, sqrt

EARTH_RADIUS = 6_371 

def haversine_distance(lat1 : float , lon1 : float, lat2 : float, lon2 : float, unit : str = "m") -> float:
    R = EARTH_RADIUS if unit == "km" else EARTH_RADIUS * 1_000
    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))
    return R * c

# %%
import json 
class DeliveryOrder:
    def __init__(self, id : str, origin_lat : float, origin_long : float, dest_lat : float, dest_long : float, weight : int) -> None:
        self.id : str = id
        self.weight : int = weight
        self.start_position : dict = {
            "latitude": origin_lat,
            "longitude": origin_long
        }
        self.destination_position : dict = {
            "latitude": dest_lat,
            "longitude": dest_long
        }
        self.order_status : bool = False
        
    def __repr__(self) -> str:
        return json.dumps({
            "id": self.id,
            "dest_lat": round(self.destination_position['latitude'],2),
            "dest_long": round(self.destination_position['longitude'],2),
            "weight": self.weight
        })

# %%
import time

def timeit(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        for _ in range(1000):
            func(*args, **kwargs)
        end_time = time.time()
        print(f"Function '{func.__name__}' took {(end_time - start_time):.6f} seconds to run 1000 times.")
    return wrapper

# %%
# ----------------------------------------------------------------------------------------------

from itertools import combinations

# ---------------------------------------------------------------------------------------------

def closest_order(latitude, longitude, orders : list[DeliveryOrder]) -> DeliveryOrder:
    min_dist = float('inf')
    closest = None
    for order in orders:
        dist = haversine_distance(
            latitude,
            longitude,
            order.destination_position['latitude'],
            order.destination_position['longitude']
        )
        if dist < min_dist:
            min_dist = dist
            closest = order
    return closest

# ---------------------------------------------------------------------------------------------

def generate_path(orders: list[DeliveryOrder], first_order: DeliveryOrder) -> list[DeliveryOrder]:
    if not orders:
        return []
    start_order = first_order
    if start_order not in orders:
        return []
    path = [start_order]
    visited = {start_order.id} 
    current_order = start_order
    while len(path) < len(orders):
        next_order = None
        min_distance = float('inf')
        for order in orders:
            if order.id not in visited:  
                distance = haversine_distance(
                    current_order.destination_position['latitude'], 
                    current_order.destination_position['longitude'], 
                    order.destination_position['latitude'], 
                    order.destination_position['longitude']
                )
                if distance < min_distance:
                    min_distance = distance
                    next_order = order
        if next_order:
            visited.add(next_order.id)  
            path.append(next_order)
            current_order = next_order
        else:
            break 
    return path

# ---------------------------------------------------------------------------------------------

def calculate_travel_distance(path : list[DeliveryOrder]) -> float:
    if len(path) < 2:
        return 0.0
    total_distance = 0.0
    for i in range(len(path) - 1):
        start = path[i]
        end = path[i + 1]
        total_distance += haversine_distance(
            start.destination_position['latitude'], 
            start.destination_position['longitude'], 
            end.destination_position['latitude'], 
            end.destination_position['longitude']
        )
    return total_distance

# ---------------------------------------------------------------------------------------------

def calculate_capacity_level(orders: list[DeliveryOrder], max_capacity: int) -> float:
    total_weight = sum(order.weight for order in orders)
    capacity_level = total_weight / max_capacity
    return min(capacity_level, 1.0)

# ---------------------------------------------------------------------------------------------

def utility(travel_distance : float, velocity : float, capacity_level : float) -> float:
    travel_time = travel_distance / velocity
    time_k = 0.1
    capacity_k = 2.0
    if travel_time <= 0:
        return float('-inf')
    # decreases with increasing travel time, sharply penalizes near-zero travel time
    travel_utility = - time_k * (1 / travel_time + travel_time)
    # maximize at capacity_level == 1, penalize deviation from 1
    capacity_utility = - capacity_k * (1 - capacity_level)**2
    # TODO: penalizes solutions that do not have enough autonomy to recharge in X warehouses
    autonomy_utility = 0.0
    return travel_utility + capacity_utility + autonomy_utility

# ---------------------------------------------------------------------------------------------

def combine_orders(orders : list[DeliveryOrder], capacity : int) -> list[list[DeliveryOrder]]:
    all_combinations = []
    for r in range(1, len(orders) + 1):
        all_combinations.extend(combinations(orders, r))
    valid_combinations = []
    for combo in all_combinations:
        if sum(order.weight for order in combo) <= capacity:
            valid_combinations.append(list(combo))
    return valid_combinations

# ---------------------------------------------------------------------------------------------

def best_available_orders(orders: list[DeliveryOrder], latitude: float, longitude: float, capacity: int, velocity: float) -> list[DeliveryOrder]:
    order_sets = combine_orders(orders, capacity)
    best_set = None
    best_utility = float('-inf')
    for order_set in order_sets:
        first_order = closest_order(latitude, longitude, order_set)
        path = generate_path(order_set, first_order)
        travel_distance = calculate_travel_distance(path)
        capacity_level = calculate_capacity_level(order_set, capacity)
        set_utility = utility(travel_distance, velocity, capacity_level)
        print(f"Order Set: {order_set} - Utility: {set_utility} vs Best Utility: {best_utility}")
        if set_utility > best_utility:
            best_set = order_set
            best_utility = set_utility
    return best_set

# ----------------------------------------------------------------------------------------------

def best_order_decision(self) -> str:
    winner = None
    drone_utility = float('-inf')
    
    if self.next_orders:
        orders = self.next_orders
        closest = closest_order(self.position["latitude"], self.position["longitude"], orders)
        distance_closest_order = haversine_distance(
            self.position["latitude"], 
            self.position["longitude"], 
            closest.destination_position['latitude'], 
            closest.destination_position['longitude']
        )
        path = generate_path(orders, closest)
        travel_distance = distance_closest_order + calculate_travel_distance(path)
            
        capacity_level = calculate_capacity_level(orders, self.params.max_capacity)
        drone_utility = utility(travel_distance, self.params.velocity, capacity_level)
        
    # print available_order_sets
    print(f"{self.params.id} - [BEST ORDER DECISION] - {self.available_order_sets}")
    
    for warehouse, orders in self.available_order_sets.items():
        if self.next_orders:
            orders += self.next_orders
        distance_warehouse = haversine_distance(
            self.position["latitude"], 
            self.position["longitude"], 
            self.warehouse_positions[warehouse]['latitude'], 
            self.warehouse_positions[warehouse]['longitude']
        )
        closest_to_warehouse = closest_order(
            self.warehouse_positions[warehouse]['latitude'], 
            self.warehouse_positions[warehouse]['longitude'], 
            orders
        )
        distance_warehouse_to_closest_order = haversine_distance(
            self.warehouse_positions[warehouse]['latitude'], 
            self.warehouse_positions[warehouse]['longitude'], 
            closest_to_warehouse.destination_position['latitude'], 
            closest_to_warehouse.destination_position['longitude']
        )
        path = generate_path(orders, closest_to_warehouse)
        travel_distance = distance_warehouse + distance_warehouse_to_closest_order + calculate_travel_distance(path)
            
        orders += self.next_orders
        capacity_level = calculate_capacity_level(orders, self.params.max_capacity)
        new_utility = utility(travel_distance, self.params.velocity, capacity_level)
            
        if new_utility > drone_utility:
            winner = warehouse
            drone_utility = new_utility  
    
    return winner

# %%
orders_w1 : list[DeliveryOrder] = [
    DeliveryOrder("w_1", 1, 1, 0.1, 0.1, 5),
    DeliveryOrder("w_2", 1, 1, 0.2, 0.8, 5),
    DeliveryOrder("w_3", 1, 1, 0.3, 0.7, 5),
    DeliveryOrder("w_4", 1, 1, 0.4, 0.6, 5),
    DeliveryOrder("w_5", 1, 1, 0.5, 0.4, 5),
    DeliveryOrder("w_6", 1, 1, 0.6, 0.6, 5),
    DeliveryOrder("w_7", 1, 1, 0.7, 0.3, 5),
    DeliveryOrder("w_8", 1, 1, 0.8, 0.4, 5),
    DeliveryOrder("w_9", 1, 1, 0.9, 0.5, 5),
    DeliveryOrder("w_10",1, 1, 0.0, 0.3, 5),
]

orders_w2 : list[DeliveryOrder] = [
    DeliveryOrder("a_1", 1, 1, 0.1, 0.1, 5),
    DeliveryOrder("a_2", 1, 1, 0.2, 0.8, 5),
    DeliveryOrder("a_3", 1, 1, 0.3, 0.7, 5),
    DeliveryOrder("a_4", 1, 1, 0.4, 0.6, 5),
    DeliveryOrder("a_5", 1, 1, 0.5, 0.4, 5),
    DeliveryOrder("a_6", 1, 1, 0.6, 0.6, 5),
    DeliveryOrder("a_7", 1, 1, 0.7, 0.3, 5),
    DeliveryOrder("a_8", 1, 1, 0.8, 0.4, 5),
    DeliveryOrder("a_9", 1, 1, 0.9, 0.5, 5),
    DeliveryOrder("a_10",1, 1, 0.0, 0.3, 5),
]

# %%
w1 = best_available_orders(orders_w1, 0.4, 0.1, 20, 10)
w2 = best_available_orders(orders_w2, 0.4, 0.1, 20, 10)

print([order for order in w1])
print([order for order in w2])

available_sets = {
    "w1": w1,
    "w2": w2
}
# Out:
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -inf vs Best Utility: -inf
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}] - Utility: -786.7641409199385 vs Best Utility: -inf
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}] - Utility: -703.7543017002489 vs Best Utility: -786.7641409199385
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -648.8672007352252 vs Best Utility: -703.7543017002489
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -556.4715011086223 vs Best Utility: -648.8672007352252
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -786.7582967965308 vs Best Utility: -556.4715011086223
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -703.7564439796453 vs Best Utility: -556.4715011086223
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -847.3304734918379 vs Best Utility: -556.4715011086223
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -995.0484790683755 vs Best Utility: -556.4715011086223
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -249.1393539625848 vs Best Utility: -556.4715011086223
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}] - Utility: -157.7526784719304 vs Best Utility: -249.1393539625848
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -315.004543024716 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -556.4676058319551 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -497.7762239305489 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -786.7535065849274 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -802.3275099015667 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -847.3284721063051 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -599.3019740817534 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -157.75195994831154 vs Best Utility: -157.7526784719304
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -401.4121296848404 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -352.1281362264467 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -629.5008950159558 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -648.8638316340739 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -703.754301794219 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -556.4730253468875 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -249.13329481241377 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -222.88989825519772 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -472.24900406661646 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -497.7731944418456 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -567.4836459567185 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -556.4730253468877 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -249.1302652742437 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -249.13670314494766 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -334.08480991106313 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -458.9663820005205 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -567.484841624234 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -352.1088562073742 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -314.99496292334135 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -352.12620833260206 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -746.4155309311597 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -157.74669094230637 vs Best Utility: -157.75195994831154
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -314.99137051072694 vs Best Utility: -157.74669094230637
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -778.8644993593626 vs Best Utility: -157.74669094230637
# Order Set: [{"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -157.7447750130829 vs Best Utility: -157.74669094230637
# Order Set: [{"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -896.9817219222914 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1025.6645954239846 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}] - Utility: -860.6319139816817 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -962.9967069261352 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -1112.0640799606817 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -1283.6594956900508 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1489.6349303400816 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1588.216631928488 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1633.2175946224556 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -847.5662829256524 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -805.7440940807539 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -957.0085983143977 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -1055.0074047476805 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1332.3801741044379 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1351.7431110898153 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1406.6335821650564 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -804.7373335324319 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -804.7297501430835 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -870.8820500852431 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1120.241177108414 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1145.765368372783 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1215.4758218594677 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -804.7373335324321 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -804.7267206044701 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -804.733158476116 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -889.6812742973245 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1014.5628531684341 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -815.7491499913106 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1054.9902670066422 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1100.8782242890788 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1138.0094727596113 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -994.6798413232491 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -860.6280687291279 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1017.8727782990471 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1027.128809992657 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1004.2001830604518 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1145.2460332439593 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1273.928907263639 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -314.6295430321031 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -558.2897375375586 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -509.00574231826295 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -786.3785067162544 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -805.7414435034729 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1004.2060851368763 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -713.3506362611946 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -563.2627835788461 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -719.7910710054515 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -786.3785068161166 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1116.4570176166344 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1161.4579801370026 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -870.60253007702 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -746.0314422813799 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1035.0151664548619 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1135.5372861711062 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1305.4198281473118 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1154.8945538867727 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -849.0100433678361 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -811.8961472660699 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1198.5796485349258 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1096.2031703261785 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -959.1991352047168 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1161.4448076217793 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1377.2914511549386 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1004.1981816749109 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1400.7544619514447 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1445.7554245966764 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -406.0101755861174 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -509.00502379438126 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -629.125895123205 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -805.7407249795745 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -860.6311955517521 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -713.3499177372992 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -600.3833495006755 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -877.7625534375699 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -982.0736063281433 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1104.2914013729346 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -957.0101225526953 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -703.3619497739455 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -666.2480539258777 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1055.0054769476674 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -907.7261261657685 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -805.7354559715195 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1017.8706361135982 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1185.098894917134 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -860.6240106137147 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1204.4618318743624 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1259.3523028763925 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -471.14509957350714 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -720.5072513429543 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -746.0314423312143 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -815.7418951727159 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -804.7312743813745 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -574.1236984774378 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -537.0098030414141 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -574.1410506035426 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -778.4878734969986 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -654.6448169584887 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -881.5999783774955 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1027.8469999595632 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -654.6429010285351 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1053.371191187034 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1123.0816445849912 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -600.3640694805787 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -563.2501739382404 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -600.3814216067285 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -994.6707526335297 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -406.0083149111795 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -563.2530193969186 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1027.1261591746163 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -490.9545117252896 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1230.1914988308924 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1483.7559525983434 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -471.8665796723117 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -666.2425336190238 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1097.6493544029086 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -508.99591096259815 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1060.5354580814526 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1097.6667065293957 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -314.61637056325503 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1053.8533476056239 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1339.7809318474056 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1053.8514316756427 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}] - Utility: -962.8717069335224 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -1114.136211719352 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -1357.7831135465713 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1646.7604022995358 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1662.3344058063176 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1707.3353685152426 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -961.8649463805395 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}] - Utility: -1119.1092578789685 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -1368.0332497317477 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1749.1251961240623 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1764.6991996372803 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1809.700162363851 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "w_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1119.1168412683735 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}] - Utility: -1301.8779196781727 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -1590.8616461999907 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "w_1", "dest_lat": 0.1, "dest_long": 0.1, "weight": 5}, {"id": "w_2", "dest_lat": 0.2, "dest_long": 0.8, "weight": 5}, {"id": "w_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -1691.3837663981394 vs Best Utility: -157.7447750130829
# ...
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1537.9216100069955 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1982.0497028168554 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -823.3696784067866 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1017.7456362196052 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1259.2099508558774 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -860.4990107197218 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1222.0960544567015 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1259.2273029823994 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1017.7456361661264 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1361.5834582633652 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1573.718640002739 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_3", "dest_lat": 0.3, "dest_long": 0.7, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1361.5815423333772 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}] - Utility: -942.7690718189435 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -968.293263002614 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1038.0037162963915 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1026.9930954405565 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -877.6288762037107 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -1034.8735858378 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1498.7467306455874 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -903.15115141499 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1642.388145780976 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1829.7708530875543 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -694.1314261698755 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -888.507383150606 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1129.971697265977 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -694.129510239917 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1092.8578009261682 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1129.9890493924727 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -881.4749784300235 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1210.4928173016133 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1437.4479813500502 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_4", "dest_lat": 0.4, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1210.490901371628 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}] - Utility: -720.3717974098572 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -914.7304024660815 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1378.6035465861778 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -720.3698814798958 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1459.6068737989328 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1625.4209967688867 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -563.1280194494466 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1302.3650087194683 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1588.292593604489 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_5", "dest_lat": 0.5, "dest_long": 0.4, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1515.994083617401 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}] - Utility: -666.1175336715519 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1217.6570842115725 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1412.0330432134608 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_6", "dest_lat": 0.6, "dest_long": 0.6, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1217.655168281587 vs Best Utility: -157.7447750130829
# Order Set: [{"id": "a_7", "dest_lat": 0.7, "dest_long": 0.3, "weight": 5}, {"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}, {"id": "a_10", "dest_lat": 0.0, "dest_long": 0.3, "weight": 5}] - Utility: -1339.6559318999336 vs Best Utility: -157.7447750130829
# [{"id": "w_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "w_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}]
# [{"id": "a_8", "dest_lat": 0.8, "dest_long": 0.4, "weight": 5}, {"id": "a_9", "dest_lat": 0.9, "dest_long": 0.5, "weight": 5}]
